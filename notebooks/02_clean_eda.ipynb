# %%
# Imports and paths
from pathlib import Path
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_theme(style="whitegrid")
DATA = Path("..") / "data" / "clean"
WIDE = next(DATA.glob("listings_wide_2025-05-26.csv"))   # latest file
print("Using file:", WIDE)
# Out:
# Using file: ../data/clean/listings_wide_2025-05-26.csv

# %%
# Read CSV (parse key datetime columns)
date_cols = ["sold_dt", "list_start", "list_end", "snapshot_ts"]
df = pd.read_csv(
    WIDE,
    parse_dates=date_cols,
    dtype={"category_id": "Int64", "leaf_cat": "Int64"}
)
print(f"{len(df):,} rows · {df.shape[1]} columns")
# Out:
# 15,000 rows · 31 columns

# %%
# Quick peek & schema check
display(df.head())
df.info(show_counts=True)
# Out:
#                         item_id  \
# 0  v1|235398389941|536188920244
# 1  v1|226383113188|525573340365
# 2  v1|235791015716|536172745216
# 3  v1|225970676295|525594915113
# 4  v1|354393355064|624218404647
#
#                                                title                condition  \
# 0  Apple iPhone 12, 64/128/256GB -  Unlocked - Us...                     Used
# 1  Apple iPhone 12 Pro, 128/256/512GB - Fully Unl...                     Used
# 2  Apple iPhone 13, 128/256/512GB - Unlocked - Us...                     Used
# 3  Apple iPhone 12, 64/128/256GB -  Unlocked - Us...                     Used
# 4  Apple iPhone 13 A2482 128GB Network Unlocked V...  Very Good - Refurbished
#
#    category_id sold_dt  sold_price  currency           seller  feedback  \
# 0         <NA>     NaT         NaN       NaN  electronicdea1s     10796
# 1         <NA>     NaT         NaN       NaN  electronicdea1s     10796
# 2         <NA>     NaT         NaN       NaN  electronicdea1s     10796
# ...

# %%
# Missing-value profile 
import missingno as msno
msno.matrix(df.sample(2500, random_state=1))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[12], line 2
#       1 # Missing-value profile
# ----> 2 import missingno as msno
#       3 msno.matrix(df.sample(2500, random_state=1))
#
# ModuleNotFoundError: No module named 'missingno'
