# %%
import pandas as pd

# %%
import pandas as pd
df = pd.read_csv("../data/clean/listings_wide_2025-05-26.csv")
df.columns

# %%
df["title_len"] = df["title"].str.len()

# %%
df[["title_len","sold_price"]].corr(method="spearman")
# Out:
#             title_len  sold_price
# title_len         1.0         NaN
# sold_price        NaN         NaN

# %%
import pandas as pd

# ── 1) load --------------------------------------------------------------------
csv_path = "../data/clean/listings_wide_2025-05-26.csv"
df = pd.read_csv(csv_path)

# %%
# ── 2) basic shape -------------------------------------------------------------
print(f"{df.shape[0]:,} rows  ×  {df.shape[1]} columns")

# ── 3) list every column name --------------------------------------------------
print("\nColumns:\n", "\n ".join(df.columns))
# Out:
# 15,000 rows  ×  31 columns
#
# Columns:
#  item_id
#  title
#  condition
#  category_id
#  sold_dt
#  sold_price
#  currency
#  seller
#  feedback
#  top_rated
#  ship_cost
#  qty_listed
#  qty_sold
#  format
#  list_start
#  list_end
#  snapshot_ts
#  group_type
#  leaf_cat
#  cat_name
#  image_url
#  thumb_url
#  seller_zip
#  seller_country
#  buy_opt
#  origin_dt
#  item_dt
#  priority_listing
#  coupon_flag
#  product_epid
#  title_len

# %%
# ── 4) data-types, null counts -------------------------------------------------
df.info(show_counts=True)

# ── 5) quick numeric summary (add include='all' to see object columns too) -----
df.describe().T                # transpose → one row per column

# ── 6) first few records (wide view) ------------------------------------------
display(df.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15000 entries, 0 to 14999
# Data columns (total 31 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   item_id           15000 non-null  object
#  1   title             15000 non-null  object
#  2   condition         15000 non-null  object
#  3   category_id       0 non-null      float64
#  4   sold_dt           0 non-null      float64
#  5   sold_price        0 non-null      float64
#  6   currency          0 non-null      float64
#  7   seller            15000 non-null  object
#  8   feedback          15000 non-null  int64
#  9   top_rated         0 non-null      float64
#  10  ship_cost         14472 non-null  float64
#  11  qty_listed        0 non-null      float64
#  12  qty_sold          0 non-null      float64
#  13  format            0 non-null      float64
#  14  list_start        0 non-null      float64
#  15  list_end          0 non-null      float64
# ...
